# %% [markdown]
# ### Building a basic chatbot using LangGraph (Graph API)

# %%
from typing import Annotated
from typing_extensions import TypedDict

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 4
#       1 from typing import Annotated
#       2 from typing_extensions import TypedDict
#       3
# ----> 4 from langgraph.graph import StateGraph, START, END
#       5 from langgraph.graph.message import add_messages
#
# File a:\AgenticLangGraph\.venv\Lib\site-packages\langgraph\graph\__init__.py:2
#       1 from langgraph.constants import END, START
# ----> 2 from langgraph.graph.message import MessageGraph, MessagesState, add_messages
#       3 from langgraph.graph.state import StateGraph
#       5 __all__ = (
#       6     "END",
#       7     "START",
#    (...)     11     "MessageGraph",
#      12 )
#
# File a:\AgenticLangGraph\.venv\Lib\site-packages\langgraph\graph\message.py:26
#      23 from typing_extensions import TypedDict, deprecated
#      25 from langgraph._internal._constants import CONF, CONFIG_KEY_SEND, NS_SEP
# ---> 26 from langgraph.graph.state import StateGraph
#      27 from langgraph.warnings import LangGraphDeprecatedSinceV10
#      29 __all__ = (
#      30     "add_messages",
#      31     "MessagesState",
#      32     "MessageGraph",
#      33     "REMOVE_ALL_MESSAGES",
#      34 )
#
# File a:\AgenticLangGraph\.venv\Lib\site-packages\langgraph\graph\state.py:28
#      14 from types import NoneType as NoneType
#      15 from typing import (
#      16     Any,
#      17     Generic,
#    (...)     25     overload,
#      26 )
# ---> 28 from langchain_core.runnables import Runnable, RunnableConfig
#      29 from langgraph.cache.base import BaseCache
#      30 from langgraph.checkpoint.base import Checkpoint
#
# File a:\AgenticLangGraph\.venv\Lib\site-packages\langchain_core\runnables\__init__.py:130, in __getattr__(attr_name)
#     128 def __getattr__(attr_name: str) -> object:
#     129     module_name = _dynamic_imports.get(attr_name)
# --> 130     result = import_attr(attr_name, module_name, __spec__.parent)
#     131     globals()[attr_name] = result
#     132     return result
#
# File a:\AgenticLangGraph\.venv\Lib\site-packages\langchain_core\_import_utils.py:36, in import_attr(attr_name, module_name, package)
#      34 else:
#      35     try:
# ---> 36         module = import_module(f".{module_name}", package=package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File a:\AgenticLangGraph\.venv\Lib\site-packages\langchain_core\runnables\base.py:45
#      43 from langchain_core._api import beta_decorator
#      44 from langchain_core._api.deprecation import warn_deprecated
# ---> 45 from langchain_core.callbacks.manager import AsyncCallbackManager, CallbackManager
#      46 from langchain_core.load.serializable import (
#      47     Serializable,
#      48     SerializedConstructor,
#      49     SerializedNotImplemented,
#      50 )
#      51 from langchain_core.runnables.config import (
#      52     RunnableConfig,
#      53     acall_func_with_variable_args,
#    (...)     63     set_config_context,
#      64 )
#
# File a:\AgenticLangGraph\.venv\Lib\site-packages\langchain_core\callbacks\manager.py:33
#      31 from langchain_core.messages import BaseMessage, get_buffer_string
#      32 from langchain_core.utils.env import env_var_is_set
# ---> 33 from langchain_core.utils.uuid import uuid7
#      35 if TYPE_CHECKING:
#      36     from collections.abc import AsyncGenerator, Coroutine, Generator, Sequence
#
# File a:\AgenticLangGraph\.venv\Lib\site-packages\langchain_core\utils\uuid.py:12
#       9 import typing
#      10 from uuid import UUID
# ---> 12 from uuid_utils.compat import uuid7 as _uuid_utils_uuid7
#      14 if typing.TYPE_CHECKING:
#      15     from uuid import UUID
#
# File a:\AgenticLangGraph\.venv\Lib\site-packages\uuid_utils\__init__.py:4
#       1 import os
#       2 from uuid import SafeUUID
# ----> 4 from ._uuid_utils import (
#       5     MAX,
#       6     NAMESPACE_DNS,
#       7     NAMESPACE_OID,
#       8     NAMESPACE_URL,
#       9     NAMESPACE_X500,
#      10     NIL,
#      11     RESERVED_FUTURE,
#      12     RESERVED_MICROSOFT,
#      13     RESERVED_NCS,
#      14     RFC_4122,
#      15     UUID,
#      16     __version__,
#      17     getnode,
#      18     uuid1,
#      19     uuid3,
#      20     uuid4,
#      21     uuid5,
#      22     uuid6,
#      23     uuid7,
#      24     uuid8,
#      25 )
#      26 from ._uuid_utils import (
#      27     _uuid4_int as _uuid4_int,
#      28 )
#      29 from ._uuid_utils import (
#      30     _uuid7_int as _uuid7_int,
#      31 )
#
# ImportError: DLL load failed while importing _uuid_utils: An Application Control policy has blocked this file.
